# %% [markdown]
# ### Lecture 1
# ### print function

# %%
print("hello Lyon 10")
# Out:
# hello Lyon 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Markdown

# %% [markdown]
# **Function**
#
# <code> print("Hello") <code>
#
#
# *Latex*
#
# $x^2+2x+1$

# %% [markdown]
# ### Shalow and deep copy
#
# A shallow copy creates a new array, but it does not create new copies of the elements within the array. Instead, it points to the same elements as the original array. A deep copy, on the other hand, creates a completely independent copy of both the array and its data. It does not share any data with the original array.

# %% [markdown]
#  ```
#   | Column 1 | Column 2 | Column 3 |
#   |----------|----------|----------|
#   | Row 1    | Row 1    | Row 1    |
#   | Row 2    | Row 2    | Row 2    |
#   ```

# %% [markdown]
# **Exercise 1**: Create a cell with a title and a paragraph with bold and italic text.

# %%
#code here
print("Hello python")
# Out:
# Hello python

# %%
message = "Hello Python"
print(message)
# Out:
# Hello Python

# %%
var_1 = "Lyon"
print(var_1)
# Out:
# Lyon

# %%
print("sdfsfd")
# Out:
# sdfsfd

# %% [markdown]
# **2-1. Simple Message:** Assign a message to a variable, and then print that
# message.
#
# **2-2. Simple Messages:** Assign a message to a variable, and print that message. Then change the value of the variable to a new message, and print the new
# messag

# %%
#2-1, 2-2
message = "asdsf"
print(message)
message = "new message"
print(message)
# Out:
# asdsf
# new message

# %%
mes_1 = 'Lyon-Isfa'

# %%
mes_2 = 'I say "Hello"'

# %%
mes_3 = "he's...."

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
mes_4 = """The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is "better" than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense."""
print(mes_4)
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is "better" than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.

# %%
mess_5 = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.'''
print(mess_5)
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.

# %%
mes_6 = '''Học viện Khoa học Tài chính và Bảo hiểm – ISFA (Institut de Science Financiere et d’Assurances), trực thuộc Đại học Tổng hợp Claude Bernard Lyon 1, là cơ sở thực hiện chương trình liên kết đào tạo Cử nhân và Thạc sĩ chuyên ngành Actuary (Định phí bảo hiểm và Quản trị rủi ro) giữa Trường đại học KTQD và Trường Đại học Tổng hợp Claude Bernard Lyon 1 của Cộng hòa Pháp.

'''
print(mes_6)
# Out:
# Học viện Khoa học Tài chính và Bảo hiểm – ISFA (Institut de Science Financiere et d’Assurances), trực thuộc Đại học Tổng hợp Claude Bernard Lyon 1, là cơ sở thực hiện chương trình liên kết đào tạo Cử nhân và Thạc sĩ chuyên ngành Actuary (Định phí bảo hiểm và Quản trị rủi ro) giữa Trường đại học KTQD và Trường Đại học Tổng hợp Claude Bernard Lyon 1 của Cộng hòa Pháp.

# %%
mes_7 = "ISFA và chương trình đào tạo Actuary"
print(mes_7.title())
print(mes_7.upper())
print(mes_7.lower())
# Out:
# Isfa Và Chương Trình Đào Tạo Actuary
# ISFA VÀ CHƯƠNG TRÌNH ĐÀO TẠO ACTUARY
# isfa và chương trình đào tạo actuary

# %%
name = "Long"
surname = "Nguyen Tuan"
full_name = f"{surname} {name}"
print(full_name)
# Out:
# Nguyen Tuan Long

# %%
name = "Long"
surname = "Nguyen Tuan"
full_name = "{} {}".format(surname,name)
print(full_name)
# Out:
# Nguyen Tuan Long

# %%
mess = "{} and\n"*20
print(mess.format(*range(20)))
# Out:
# 0 and
# 1 and
# 2 and
# 3 and
# 4 and
# 5 and
# 6 and
# 7 and
# 8 and
# 9 and
# 10 and
# 11 and
# 12 and
# 13 and
# 14 and
# 15 and
# 16 and
# 17 and
# 18 and
# 19 and

# %% [markdown]
# **2-3. Personal Message:** Use a variable to represent a person’s name, and print a message to that person. Your message should be simple, such as, “Hello Eric, would you like to learn some Python today?”
#
# **2-4. Name Cases:** Use a variable to represent a person’s name, and then print that person’s name in lowercase, uppercase, and title case.

# %%
#2-3
name = "Eric"
print("Hello {}, would you like to learn some Python today?".format(name))
# Out:
# Hello Eric, would you like to learn some Python today?

# %%
#2-4
name_1 = "Nguyen Ngoc Quynh"
print(name_1.lower())
print(name_1.upper())
print(name_1.title())
# Out:
# nguyen ngoc quynh
# NGUYEN NGOC QUYNH
# Nguyen Ngoc Quynh

# %% [markdown]
# **2-5. Famous Quote:** Find a quote from a famous person you admire. Print the quote and the name of its author.Your output should look something like the following,including the quotation marks:
# Albert Einstein once said, “A person who never made a
# mistake never tried anything new."

# %%
mes_8 = 'Albert Einstein once said,"A person who never made a mistake never tried anything new."'
print(mes_8)
# Out:
# Albert Einstein once said,"A person who never made a mistake never tried anything new."

# %% [markdown]
# **2-6. Famous Quote 2:** Repeat Exercise 2-5, but this time, represent the famous person’s name using a variable called famous_person. Then compose your message and represent it with a new variable called message. Print your message.

# %%
famous_person = "Albert Einstein"
mes_9 = f'{famous_person} once said,"A person who never made a mistake never tried anything new."'
print(mes_9)
# Out:
# Albert Einstein once said,"A person who never made a mistake never tried anything new."

# %% [markdown]
# **2-7. Stripping Names:** Use a variable to represent a person’s name, and include some whitespace characters at the beginning and end of the name. Make sure you use each character combination, "\t" and "\n", at least once.
# Print the name once, so the whitespace around the name is displayed.
# Then print the name using each of the three stripping functions, lstrip(),
# rstrip(), and strip().

# %%
mes_10 = '''   \tAlbert Einstein once said, \n “A person who never made a
mistake never tried anything new.    "'''
print(mes_10)
print(mes_10.rstrip())
print(mes_10.lstrip())
print(mes_10.strip())
# Out:
#    	Albert Einstein once said,
#  “A person who never made a
# mistake never tried anything new.    "
#    	Albert Einstein once said,
#  “A person who never made a
# mistake never tried anything new.    "
# Albert Einstein once said,
#  “A person who never made a
# mistake never tried anything new.    "
# Albert Einstein once said,
#  “A person who never made a
# mistake never tried anything new.    "

# %%
p = 0.1+0.1+0.1 == 0.3
print(p)
# Out:
# False

# %%
0.1+0.1+0.1
# Out:
# 0.30000000000000004

# %%
type(p)
# Out:
# bool

# %%
type(message)
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
type(0.1)
# Out:
# float

# %%
str(123123)
# Out:
# '123123'

# %%
str(p)
# Out:
# 'False'

# %%
int('3423')
# Out:
# 3423

# %%
int("123a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 int("123a")
#
# ValueError: invalid literal for int() with base 10: '123a'

# %%
int(3.5)
# Out:
# 3

# %%
int(False)
# Out:
# 0

# %%
float(3)
# Out:
# 3.0

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("sdfsf")
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
name = input('Your name:')

# %%
print(name)
# Out:
# Long

# %%
age = int(input('your age:'))
# age = int(age)
type(age)
# Out:
# int

# %%
n_1 = input('Number 1:')
n_2 = input("Number 2: ")
n_1, n_2 = int(n_1), int(n_2) 
print('Sum = ',n_1+n_2)
# Out:
# Sum =  57

# %%
print("ádfsf","sfđsf")
# Out:
# ádfsf sfđsf

# %%
x = 10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 x = 10/0
#
# ZeroDivisionError: division by zero

# %%
try:
    #print(7/0)
    print(x+y)
except:
    print('ZeroDivisionError: division by zero')
# Out:
# ZeroDivisionError: division by zero

# %%
alist = [1, 3.4, "atring",True, [1,2]]
print(alist)
# Out:
# [1, 3.4, 'atring', True, [1, 2]]

# %%
alist[0]
# Out:
# 1

# %%
alist[2]
# Out:
# 'atring'

# %%
alist[4]
# Out:
# [1, 2]

# %%
alist[-1]
# Out:
# [1, 2]

# %%
print(alist)
# Out:
# [1, 3.4, 'atring', True, [1, 2]]

# %%
alist[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 alist[5]
#
# IndexError: list index out of range

# %%
alist[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 alist[-6]
#
# IndexError: list index out of range
